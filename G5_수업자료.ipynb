# %% [markdown]
# <a href="https://colab.research.google.com/github/GydeokLee/DL23_Project_G5/blob/main/G5_%EC%88%98%EC%97%85%EC%9E%90%EB%A3%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# # 📗Learning with Story📗
# ## "Two Travelers and a Bear"
# ---

# %% [markdown]
# # 0. Word cloud

# %%
#@markdown 📰 Word cloud
import matplotlib.pyplot as plt
from wordcloud import WordCloud

user_text = input("Please paste your text here: ")

wordcloud = WordCloud(
    background_color='white',
    width=800,
    height=800,
    max_words=100
).generate(user_text)

plt.figure(figsize=(8, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# Please paste your text here: Two Men were traveling in company through a forest, when, all at once, a huge Bear crashed out of the brush near them. One of the Men, thinking of his own safety, climbed a tree. The other, unable to fight the savage beast alone, threw himself on the ground and lay still, as if he were dead. He had heard that a Bear will not touch a dead body. It must have been true, for the Bear snuffed at the Man's head awhile, and then, seeming to be satisfied that he was dead, walked away. The Man in the tree climbed down. "It looked just as if that Bear whispered in your ear," he said. "What did he tell you?" "He said," answered the other, "that it was not at all wise to keep company with a fellow who would desert his friend in a moment of danger."

# %% [markdown]
# # ❤️ 1. Audio File

# %%
#@markdown Install gTTS
# %%capture
# !pip install gtts
from gtts import gTTS
from IPython.display import Audio, display

def tts(text):
  gtts_object = gTTS(text,lang = "en", slow = False)
  gtts_object.save("myaudio.mp3")
  return Audio("myaudio.mp3")

# %% [markdown]
# ---

# %%
#@markdown 🎧 Listening the story
text = '''Two Men were traveling in company through a forest, when, all at once, a huge Bear crashed out of the brush near them. One of the Men, thinking of his own safety, climbed a tree. The other, unable to fight the savage beast alone, threw himself on the ground and lay still, as if he were dead. He had heard that a Bear will not touch a dead body. It must have been true, for the Bear snuffed at the Man's head awhile, and then, seeming to be satisfied that he was dead, walked away. The Man in the tree climbed down. "It looked just as if that Bear whispered in your ear," he said. "What did he tell you?" "He said," answered the other, "that it was not at all wise to keep company with a fellow who would desert his friend in a moment of danger."'''
tts(text)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # 💗 2. Make images in Bing

# %%
#@markdown 🎨 Bing QR Code

# !pip install pyqrcode

import pyqrcode
from pyqrcode import QRCode

s = input("Paste the link: ")

url = pyqrcode.create(s)

url.svg("myqrcode.svg", scale=10)

from IPython.display import SVG, display
def show_svg(file):
    display(SVG(file))

show_svg("myqrcode.svg")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyqrcode in /usr/local/lib/python3.10/dist-packages (1.2.1)
# Paste the link: https://www.bing.com/images/create?form=FLPGEN

# %% [markdown]
# # 💛 3. Upload images in Padlet

# %%
#@markdown 📋 Padlet QR Code
# !pip install pyqrcode

import pyqrcode
from pyqrcode import QRCode

s = input("Paste the link: ")

url = pyqrcode.create(s)

url.svg("myqrcode.svg", scale=10)

from IPython.display import SVG, display
def show_svg(file):
    display(SVG(file))

show_svg("myqrcode.svg")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyqrcode in /usr/local/lib/python3.10/dist-packages (1.2.1)
# Paste the link: https://padlet.com/dbdb7214/learning-with-story-r3aahxb9dl0elcg8

# %% [markdown]
# # 💚 4. Show images made by a teacher

# %%
#@markdown 🐻 Lecture slides (#1~3)
from IPython.display import Image

pages = "1" #@param = ["1", "2", "3"]
adds = ['https://github.com/Son324/Images/raw/96843772e5cd4a08cef1abcf50d53a9e9c9d17e6/Bear(1).jfif',
        'https://github.com/Son324/Images/raw/96843772e5cd4a08cef1abcf50d53a9e9c9d17e6/The%20bear%20walked%20away.jfif',
        'https://github.com/Son324/Images/raw/96843772e5cd4a08cef1abcf50d53a9e9c9d17e6/Two%20man%20talking.jfif']
if pages == "1":
  add = adds[0]
elif pages == "2":
  add = adds[1]
elif pages == "3":
  add = adds[2]
Image(url=add, width=800, height=500)
# Out:
# <img src="https://github.com/Son324/Images/raw/96843772e5cd4a08cef1abcf50d53a9e9c9d17e6/Bear(1).jfif" width="800" height="500"/>

# %% [markdown]
# # 💙 5. Show the text and teach

# %%
#@markdown ## 🐻 "Two Travelers and a Bear"
from IPython.display import Image, display

image_url = 'https://github.com/GydeokLee/DL23_Project_G5/raw/main/%EC%9D%B4%EC%86%9D%EC%9A%B0%ED%99%94.png'

display(Image(url=image_url, width=800, height=500))
# Out:
# <img src="https://github.com/GydeokLee/DL23_Project_G5/raw/main/%EC%9D%B4%EC%86%9D%EC%9A%B0%ED%99%94.png" width="800" height="500"/>

# %% [markdown]
# # 💜 6. Quiz

# %%
#@markdown 💯 Quiz QR Code
# !pip install pyqrcode

import pyqrcode
from pyqrcode import QRCode

s = input("Paste the link: ")

url = pyqrcode.create(s)

url.svg("myqrcode.svg", scale=10)

from IPython.display import SVG, display
def show_svg(file):
    display(SVG(file))

show_svg("myqrcode.svg")

#Quiz url: https://docs.google.com/forms/d/e/1FAIpQLSdp4M5yIz5VBxOKK7VMA4Zo0IJGETnMRsNB_dtKYctPzs60Mw/viewform?usp=sf_link
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyqrcode
#   Downloading PyQRCode-1.2.1.zip (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pyqrcode
#   Building wheel for pyqrcode (setup.py) ... done
#   Created wheel for pyqrcode: filename=PyQRCode-1.2.1-py3-none-any.whl size=36228 sha256=8623ceedd7ff2073ec5d61a80da267feae326e43baede4ee72b16c8d03b94dc5
#   Stored in directory: /root/.cache/pip/wheels/34/2d/20/082874e49a32cdcc87ebaf99dd0099fb7774ef30f010dfb6f2
# Successfully built pyqrcode
# Installing collected packages: pyqrcode
# Successfully installed pyqrcode-1.2.1
# Paste the link: https://docs.google.com/forms/d/e/1FAIpQLSdp4M5yIz5VBxOKK7VMA4Zo0IJGETnMRsNB_dtKYctPzs60Mw/viewform?usp=sf_link

# %% [markdown]
# # Text & Link

# %% [markdown]
# Story text: Two Men were traveling in company through a forest, when, all at once, a huge Bear crashed out of the brush near them.  One of the Men, thinking of his own safety, climbed a tree.  The other, unable to fight the savage beast alone, threw himself on the ground and lay still, as if he were dead. He had heard that a Bear will not touch a dead body.  It must have been true, for the Bear snuffed at the Man's head awhile, and then, seeming to be satisfied that he was dead, walked away.  The Man in the tree climbed down.  "It looked just as if that Bear whispered in your ear," he said. "What did he tell you?"  "He said," answered the other, "that it was not at all wise to keep company with a fellow who would desert his friend in a moment of danger."

# %% [markdown]
# Bing: https://www.bing.com/images/create?form=FLPGEN

# %% [markdown]
# Padlet: https://padlet.com/dbdb7214/learning-with-story-r3aahxb9dl0elcg8

# %% [markdown]
# Quiz: https://docs.google.com/forms/d/e/1FAIpQLSdp4M5yIz5VBxOKK7VMA4Zo0IJGETnMRsNB_dtKYctPzs60Mw/viewform
